# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
courses_df = pd.read_excel("courses.xlsx")
courses_df.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#   CourseCode Pre-requisites Level  \
# 0      AS400            NaN   400
# 1      AS401            NaN   400
# 2      AS402            NaN   400
# 3      AS403            NaN   400
# 4      AS404            NaN   400
#
#                                     CourseName  \
# 0                        Industrial Management
# 1                         Industrial Placement
# 2  Research methodology and scientific writing
# 3                                      Seminar
# 4    Data Integrity Management & Data Analysis
#
#                                           Department Credits  \
# 0  Department of Environmental & Industrial Sciences       2
# 1  Department of Environmental & Industrial Sciences       8
# 2  Department of Environmental & Industrial Sciences       2
# 3  Department of Environmental & Industrial Sciences       1
# 4  Department of Environmental & Industrial Sciences       2
#
#                                          Description
# 0  Approaches to Management: Introduction to Mana...
# 1  Train students with work experience in an indu...
# 2  Methods of Research: To provide skills of surv...
# 3  Under this course undergraduate students will ...
# 4  Data Integrity Management: Good laboratory pra...

# %%
courses_df['CourseCode'].nunique()
# Out:
# 686

# %% [markdown]
# # Data Cleaning

# %%
courses_df.shape
# Out:
# (754, 7)

# %%
courses_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CourseCode      752 non-null    object
#  1   Pre-requisites  356 non-null    object
#  2   Level           752 non-null    object
#  3   CourseName      750 non-null    object
#  4   Department      744 non-null    object
#  5   Credits         712 non-null    object
#  6   Description     604 non-null    object
# dtypes: object(7)
# memory usage: 41.4+ KB

# %% [markdown]
# # Check Null Values

# %%
courses_df.isnull().sum()
# Out:
# CourseCode          2
# Pre-requisites    398
# Level               2
# CourseName          4
# Department         10
# Credits            42
# Description       150
# dtype: int64

# %%
# check null values in courseCode column
null_values = courses_df['CourseCode'].isnull()
courses_df[null_values]
# Out:
#     CourseCode Pre-requisites Level                  CourseName  \
# 230        NaN            NaN     0         Precambrian Geology
# 241        NaN            NaN     0  Environmental Geochemistry
#
#                 Department Credits Description
# 230  Department of Geology       2         NaN
# 241  Department of Geology       2         NaN

# %%
# check null values in level column
courses_df['Level'].isnull().sum()
# Out:
# 2

# %% [markdown]
# # Handling null Values

# %%
courses_df = courses_df.dropna(subset=['CourseCode'])

# %%
courses_df.isnull().sum()
# Out:
# CourseCode          0
# Pre-requisites    396
# Level               2
# CourseName          4
# Department         10
# Credits            42
# Description       148
# dtype: int64

# %%
courses_df[courses_df['Department'].isnull()]
# Out:
#     CourseCode Pre-requisites Level  \
# 77       BT421            NaN   400
# 165    ECN2013            NaN   200
# 166    ECN3012        ECN2013   300
# 170     FND114            NaN   100
# 180      ES312            NaN   300
# 183      ES315            NaN   300
# 185      ES401            NaN   400
# 300     FNA102            NaN   NaN
# 301     ESS106            NaN   NaN
# 302      MT102            NaN   100
#
#                                     CourseName Department Credits Description
# 77                                         NaN        NaN     NaN         NaN
# 165               Introductory Economic Theory        NaN       3         NaN
# 166                     The Sri Lankan Economy        NaN       2         NaN
# 170                             Law and Ethics        NaN     NaN         NaN
# 180  Biodiversity, Conservation and Management        NaN     NaN         NaN
# 183                      Advanced Microbiology        NaN     NaN         NaN
# 185            Geologic and Hydrologic Hazards        NaN     NaN         NaN
# 300                                        NaN        NaN     NaN         NaN
# 301                                        NaN        NaN     NaN         NaN
# 302        Introduction to Probability Theory         NaN       3         NaN

# %%
courses_df['Pre-requisites'].fillna('No Pre-requisites',inplace=True)

# %%
courses_df[courses_df['Level'].isnull()]
# Out:
#     CourseCode     Pre-requisites Level CourseName Department Credits  \
# 300     FNA102  No Pre-requisites   NaN        NaN        NaN     NaN
# 301     ESS106  No Pre-requisites   NaN        NaN        NaN     NaN
#
#     Description
# 300         NaN
# 301         NaN

# %%
courses_df['Level'].replace(pd.NA,'100', inplace=True)

# %%
courses_df['Level'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Check Duplicates

# %%
courses_df.duplicated().sum()
# Out:
# 5

# %%
courses_df['CourseCode'].nunique()
# Out:
# 686

# %%
courses_df[courses_df.duplicated()]
# Out:
#     CourseCode     Pre-requisites Level  \
# 469      BT420              BT302   400
# 629    GEO1033            GEO1013  1000
# 630    GEO1041            GEO1033  1000
# 708    BOT2072  No Pre-requisites  2000
# 747    BMS4043  No Pre-requisites  4000
#
#                                 CourseName             Department Credits  \
# 469           Biological Nitrogen Fixation   Department of Botany       2
# 629                        Earth Materials  Department of Geology       3
# 630             Earth Materials Laboratory  Department of Geology       1
# 708                     Microbial Genetics   Department of Botany     NaN
# 747  Pharmaceutical Design and Development                Zoology       3
#
#     Description
# 469         NaN
# 629          NO
# 630          NO
# 708         NaN
# 747         NaN

# %%
# remove duplicates
courses = courses_df.drop_duplicates(keep='first')
courses
# Out:
#     CourseCode     Pre-requisites Level  \
# 0        AS400  No Pre-requisites   400
# 1        AS401  No Pre-requisites   400
# 2        AS402  No Pre-requisites   400
# 3        AS403  No Pre-requisites   400
# 4        AS404  No Pre-requisites   400
# ..         ...                ...   ...
# 749    MIC4052            BOT2052  4000
# 750    MIC4062            MIC3042  4000
# 751    MIC4092  No Pre-requisites  4000
# 752    MIC4103            ZOO3232  4000
# 753    MIC4112            MIC3132  4000
#
#                                       CourseName  \
# 0                          Industrial Management
# 1                           Industrial Placement
# 2    Research methodology and scientific writing
# 3                                        Seminar
# 4      Data Integrity Management & Data Analysis
# ..                                           ...
# 749                             Plant Toxicology
# 750                                  Biosecurity
# 751                             Bio-fermentation
# 752                         Applied Parasitology
# 753           Animal Pathogens and Public Health
#
#                                             Department Credits  \
# 0    Department of Environmental & Industrial Sciences       2
# 1    Department of Environmental & Industrial Sciences       8
# 2    Department of Environmental & Industrial Sciences       2
# 3    Department of Environmental & Industrial Sciences       1
# 4    Department of Environmental & Industrial Sciences       2
# ..                                                 ...     ...
# 749                                             Botany       2
# 750                                             Botany       2
# 751                                             Botany       2
# 752                                             Botany       3
# 753                                             Botany       2
#
#                                            Description
# 0    Approaches to Management: Introduction to Mana...
# 1    Train students with work experience in an indu...
# 2    Methods of Research: To provide skills of surv...
# 3    Under this course undergraduate students will ...
# 4    Data Integrity Management: Good laboratory pra...
# ..                                                 ...
# 749                                                NaN
# 750                                                NaN
# 751                                                NaN
# 752                                                NaN
# 753                                                NaN
#
# [747 rows x 7 columns]

# %%
def transform_course_code(course_code):
    # Splitting letters and numbers
    letters = ''.join(filter(str.isalpha, course_code))
    numbers = ''.join(filter(str.isdigit, course_code))



    # Replacing letters based on the provided mapping
    replacement_map = {'BIO': 'BL', 'CSC': 'CS', 'ENG': 'EN', 'GEO': 'GL',
                       'MAT': 'MT', 'PHY': 'PH', 'SED': 'SE', 'ECN': 'EC',
                       'MGT': 'MG', 'STA': 'ST', 'CHE': 'CH', 'BOT': 'BT',
                       'ESS': 'ES', 'ZOO': 'ZL'}

    # Extracting the last four digits from numbers part
    if len(numbers) == 4 and letters in replacement_map:
        numbers = numbers[:-1]

    if letters in replacement_map:
        letters = replacement_map[letters]

    # Combining the modified letters and numbers
    transformed_code = f"{letters}{numbers}"

    return transformed_code

courses['CourseCode'] = courses['CourseCode'].apply(transform_course_code)
# Out:
# <ipython-input-37-ffa3f4d434bc>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   courses['CourseCode'] = courses['CourseCode'].apply(transform_course_code)

# %%
courses['CourseCode'].nunique()
# Out:
# 596

# %%
courses['CourseCode'].duplicated().sum()
# Out:
# 151

# %%
courses = courses.drop_duplicates(subset='CourseCode', keep='first')

# %%
# courses = courses[~courses['CourseCode'].isin(duplicates['CourseCode'])]
# courses['CourseCode'].isnull().sum()
courses['CourseCode'].count()
# Out:
# 596

# %%
courses['Department'].isnull().sum()
# Out:
# 8

# %%
courses[courses['Department'].isnull()]
# Out:
#     CourseCode     Pre-requisites Level  \
# 77       BT421  No Pre-requisites   400
# 170     FND114  No Pre-requisites   100
# 180      ES312  No Pre-requisites   300
# 183      ES315  No Pre-requisites   300
# 185      ES401  No Pre-requisites   400
# 300     FNA102  No Pre-requisites   100
# 301      ES106  No Pre-requisites   100
# 302      MT102  No Pre-requisites   100
#
#                                     CourseName Department Credits Description
# 77                                         NaN        NaN     NaN         NaN
# 170                             Law and Ethics        NaN     NaN         NaN
# 180  Biodiversity, Conservation and Management        NaN     NaN         NaN
# 183                      Advanced Microbiology        NaN     NaN         NaN
# 185            Geologic and Hydrologic Hazards        NaN     NaN         NaN
# 300                                        NaN        NaN     NaN         NaN
# 301                                        NaN        NaN     NaN         NaN
# 302        Introduction to Probability Theory         NaN       3         NaN

# %%
mapping = {
    'BT421': 'Department of Botany',
    'FND114': 'External',
    'ES312': 'Department of Environmental & Industrial Sciences',
    'ES315': 'Department of Environmental & Industrial Sciences',
    'ES401': 'Department of Environmental & Industrial Sciences',
    'FNA102' :'External',
    'ES106' :'Department of Environmental & Industrial Sciences',
    'MT102':'Department of Mathematics'
}

# Replace NaN values in 'Department' based on the mapping
courses['Department'] = courses.apply(lambda row: mapping.get(row['CourseCode'], row['Department']), axis=1)

courses['Department'].isnull().sum()
# Out:
# <ipython-input-45-8bc232f25bbf>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   courses['Department'] = courses.apply(lambda row: mapping.get(row['CourseCode'], row['Department']), axis=1)
# 0

# %% [markdown]
# # Feature selection

# %%
 courses.drop('Description',axis=1,inplace=True)
 courses.drop('Credits',axis=1,inplace=True)
 courses.drop('Level',axis=1,inplace=True)
 courses.drop('CourseName',axis=1,inplace=True)
 courses
# Out:
# <ipython-input-46-9d55f2dbebb9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   courses.drop('Description',axis=1,inplace=True)
# <ipython-input-46-9d55f2dbebb9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   courses.drop('Credits',axis=1,inplace=True)
# <ipython-input-46-9d55f2dbebb9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   courses.drop('Level',axis=1,inplace=True)
# <ipython-input-46-9d55f2dbebb9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   courses.drop('CourseName',axis=1,inplace=True)
#     CourseCode     Pre-requisites  \
# 0        AS400  No Pre-requisites
# 1        AS401  No Pre-requisites
# 2        AS402  No Pre-requisites
# 3        AS403  No Pre-requisites
# 4        AS404  No Pre-requisites
# ..         ...                ...
# 749    MIC4052            BOT2052
# 750    MIC4062            MIC3042
# 751    MIC4092  No Pre-requisites
# 752    MIC4103            ZOO3232
# 753    MIC4112            MIC3132
#
#                                             Department
# 0    Department of Environmental & Industrial Sciences
# 1    Department of Environmental & Industrial Sciences
# 2    Department of Environmental & Industrial Sciences
# 3    Department of Environmental & Industrial Sciences
# 4    Department of Environmental & Industrial Sciences
# ..                                                 ...
# 749                                             Botany
# 750                                             Botany
# 751                                             Botany
# 752                                             Botany
# 753                                             Botany
#
# [596 rows x 3 columns]

# %%
courses[courses.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CourseCode, Pre-requisites, Department]
# Index: []

# %%
courses['CourseCode'].nunique()
# Out:
# 596

# %% [markdown]
# # Data Filtering

# %%
courses= courses.drop(courses[courses['Department'] == 'External'].index)
courses[courses['Department'] == 'External']
courses
# Out:
#     CourseCode     Pre-requisites  \
# 0        AS400  No Pre-requisites
# 1        AS401  No Pre-requisites
# 2        AS402  No Pre-requisites
# 3        AS403  No Pre-requisites
# 4        AS404  No Pre-requisites
# ..         ...                ...
# 749    MIC4052            BOT2052
# 750    MIC4062            MIC3042
# 751    MIC4092  No Pre-requisites
# 752    MIC4103            ZOO3232
# 753    MIC4112            MIC3132
#
#                                             Department
# 0    Department of Environmental & Industrial Sciences
# 1    Department of Environmental & Industrial Sciences
# 2    Department of Environmental & Industrial Sciences
# 3    Department of Environmental & Industrial Sciences
# 4    Department of Environmental & Industrial Sciences
# ..                                                 ...
# 749                                             Botany
# 750                                             Botany
# 751                                             Botany
# 752                                             Botany
# 753                                             Botany
#
# [561 rows x 3 columns]

# %%
courses = courses.drop(courses[courses['CourseCode'].isin(['ECN2002'])].index)  # Remove ECN2002

# %%
courses.to_excel('coursesNEW.xlsx', index=False)
